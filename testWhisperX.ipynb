# %%
! conda create --name whisperX python=3.10 -y
! conda activate whisperX -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/jamesphoughton/opt/anaconda3/envs/whisperX
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.08.22 |       hecd8cb5_0         124 KB
#     libffi-3.4.4               |       hecd8cb5_0         132 KB
#     ncurses-6.4                |       hcec6c5f_0        1018 KB
#     openssl-3.0.11             |       hca72f7f_2         4.5 MB
#     pip-23.3                   |  py310hecd8cb5_0         2.7 MB
#     python-3.10.13             |       h5ee71fb_0        13.1 MB
#     setuptools-68.0.0          |  py310hecd8cb5_0         955 KB
#     sqlite-3.41.2              |       h6c40b1e_0         1.2 MB
#     tzdata-2023c               |       h04d1e81_0         116 KB
#     wheel-0.41.2               |  py310hecd8cb5_0         110 KB
#     xz-5.4.2                   |       h6c40b1e_0         372 KB
#     ------------------------------------------------------------
#                                            Total:        24.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/osx-64::bzip2-1.0.8-h1de35cc_0 None
#   ca-certificates    pkgs/main/osx-64::ca-certificates-2023.08.22-hecd8cb5_0 None
#   libffi             pkgs/main/osx-64::libffi-3.4.4-hecd8cb5_0 None
#   ncurses            pkgs/main/osx-64::ncurses-6.4-hcec6c5f_0 None
#   openssl            pkgs/main/osx-64::openssl-3.0.11-hca72f7f_2 None
#   pip                pkgs/main/osx-64::pip-23.3-py310hecd8cb5_0 None
#   python             pkgs/main/osx-64::python-3.10.13-h5ee71fb_0 None
#   readline           pkgs/main/osx-64::readline-8.2-hca72f7f_0 None
#   setuptools         pkgs/main/osx-64::setuptools-68.0.0-py310hecd8cb5_0 None
#   sqlite             pkgs/main/osx-64::sqlite-3.41.2-h6c40b1e_0 None
#   tk                 pkgs/main/osx-64::tk-8.6.12-h5d9f67b_0 None
#   tzdata             pkgs/main/noarch::tzdata-2023c-h04d1e81_0 None
#   wheel              pkgs/main/osx-64::wheel-0.41.2-py310hecd8cb5_0 None
#   xz                 pkgs/main/osx-64::xz-5.4.2-h6c40b1e_0 None
#   zlib               pkgs/main/osx-64::zlib-1.2.13-h4dc903c_0 None
#
#
#
# Downloading and Extracting Packages
# sqlite-3.41.2        | 1.2 MB    | ##################################### | 100%
# openssl-3.0.11       | 4.5 MB    | ##################################### | 100%
# pip-23.3             | 2.7 MB    | ##################################### | 100%
# wheel-0.41.2         | 110 KB    | ##################################### | 100%
# python-3.10.13       | 13.1 MB   | ##################################### | 100%
# ca-certificates-2023 | 124 KB    | ##################################### | 100%
# tzdata-2023c         | 116 KB    | ##################################### | 100%
# libffi-3.4.4         | 132 KB    | ##################################### | 100%
# ncurses-6.4          | 1018 KB   | ##################################### | 100%
# setuptools-68.0.0    | 955 KB    | ##################################### | 100%
# xz-5.4.2             | 372 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate whisperX
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
! pip install onnxruntime-silicon
# ! conda install onnxruntime -c conda-forge -y
! pip3 install git+https://github.com/m-bain/whisperx.git
# Out:
# Collecting onnxruntime-silicon
#   Obtaining dependency information for onnxruntime-silicon from https://files.pythonhosted.org/packages/46/b5/b99464f5df5864716655b1133f37a02e387c613c27d24862731c8e4400c9/onnxruntime_silicon-1.16.0-cp39-cp39-macosx_13_0_arm64.whl.metadata
#   Downloading onnxruntime_silicon-1.16.0-cp39-cp39-macosx_13_0_arm64.whl.metadata (4.0 kB)
# Collecting coloredlogs (from onnxruntime-silicon)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
# Collecting flatbuffers (from onnxruntime-silicon)
#   Obtaining dependency information for flatbuffers from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: numpy>=1.22.3 in ./.venv/lib/python3.9/site-packages (from onnxruntime-silicon) (1.26.1)
# Requirement already satisfied: packaging in ./.venv/lib/python3.9/site-packages (from onnxruntime-silicon) (23.2)
# Collecting protobuf (from onnxruntime-silicon)
#   Obtaining dependency information for protobuf from https://files.pythonhosted.org/packages/88/12/efb5896c901382548ecb58d0449885a8f9aa62bb559d65e5a8a47f122629/protobuf-4.24.4-cp37-abi3-macosx_10_9_universal2.whl.metadata
#   Downloading protobuf-4.24.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (540 bytes)
# Requirement already satisfied: sympy in ./.venv/lib/python3.9/site-packages (from onnxruntime-silicon) (1.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-silicon)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.9/site-packages (from sympy->onnxruntime-silicon) (1.3.0)
# Downloading onnxruntime_silicon-1.16.0-cp39-cp39-macosx_13_0_arm64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 57.2 MB/s eta 0:00:0000:0100:01
# Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Downloading protobuf-4.24.4-cp37-abi3-macosx_10_9_universal2.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.4/409.4 kB 42.0 MB/s eta 0:00:00
# Installing collected packages: flatbuffers, protobuf, humanfriendly, coloredlogs, onnxruntime-silicon
# Successfully installed coloredlogs-15.0.1 flatbuffers-23.5.26 humanfriendly-10.0 onnxruntime-silicon-1.16.0 protobuf-4.24.4
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip
# Collecting git+https://github.com/m-bain/whisperx.git
#   Cloning https://github.com/m-bain/whisperx.git to /private/var/folders/2l/3kmvzs0s1sggnw_9sl0ls8080000gn/T/pip-req-build-uj33uq_2
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperx.git /private/var/folders/2l/3kmvzs0s1sggnw_9sl0ls8080000gn/T/pip-req-build-uj33uq_2
#   Resolved https://github.com/m-bain/whisperx.git to commit 49e0130e4e0c0d99d60715d76e65a71826a97109
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2 in ./.venv/lib/python3.9/site-packages (from whisperx==3.1.1) (2.1.0)
# Collecting torchaudio>=2 (from whisperx==3.1.1)
#   Obtaining dependency information for torchaudio>=2 from https://files.pythonhosted.org/packages/9e/e2/812b1a2a5ec34fe7c0a5cf11b4e62709172fd71783cbc8b7875e3051e8a5/torchaudio-2.1.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Using cached torchaudio-2.1.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.7 kB)
# Collecting faster-whisper>=0.8 (from whisperx==3.1.1)
#   Obtaining dependency information for faster-whisper>=0.8 from https://files.pythonhosted.org/packages/ff/11/401db7f4bfdcec3c4bd685297c2fb11a3caa0a0fa3288bd209f973b877bb/faster_whisper-0.9.0-py3-none-any.whl.metadata
#   Using cached faster_whisper-0.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting transformers (from whisperx==3.1.1)
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/c1/bd/f64d67df4d3b05a460f281defe830ffab6d7940b7ca98ec085e94e024781/transformers-4.34.1-py3-none-any.whl.metadata
#   Using cached transformers-4.34.1-py3-none-any.whl.metadata (121 kB)
# Requirement already satisfied: ffmpeg-python>=0.2 in ./.venv/lib/python3.9/site-packages (from whisperx==3.1.1) (0.2.0)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from whisperx==3.1.1) (2.1.1)
# Collecting setuptools>=65 (from whisperx==3.1.1)
#   Obtaining dependency information for setuptools>=65 from https://files.pythonhosted.org/packages/bb/26/7945080113158354380a12ce26873dd6c1ebd88d47f5bc24e2c5bb38c16a/setuptools-68.2.2-py3-none-any.whl.metadata
#   Using cached setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: nltk in ./.venv/lib/python3.9/site-packages (from whisperx==3.1.1) (3.8.1)
# Collecting pyannote.audio==3.0.1 (from whisperx==3.1.1)
#   Obtaining dependency information for pyannote.audio==3.0.1 from https://files.pythonhosted.org/packages/ec/05/46bf2216c6f89ab8f0b0c1be3a7f34808ae105df86ca682d2c040a0b5cb4/pyannote.audio-3.0.1-py2.py3-none-any.whl.metadata
#   Using cached pyannote.audio-3.0.1-py2.py3-none-any.whl.metadata (7.8 kB)
# Collecting asteroid-filterbanks>=0.4 (from pyannote.audio==3.0.1->whisperx==3.1.1)
#   Using cached asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Collecting einops>=0.6.0 (from pyannote.audio==3.0.1->whisperx==3.1.1)
#   Obtaining dependency information for einops>=0.6.0 from https://files.pythonhosted.org/packages/29/0b/2d1c0ebfd092e25935b86509a9a817159212d82aa43d7fb07eca4eeff2c2/einops-0.7.0-py3-none-any.whl.metadata
#   Using cached einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting huggingface-hub>=0.13.0 (from pyannote.audio==3.0.1->whisperx==3.1.1)
#   Obtaining dependency information for huggingface-hub>=0.13.0 from https://files.pythonhosted.org/packages/ef/b5/b6107bd65fa4c96fdf00e4733e2fe5729bb9e5e09997f63074bb43d3ab28/huggingface_hub-0.18.0-py3-none-any.whl.metadata
#   Using cached huggingface_hub-0.18.0-py3-none-any.whl.metadata (13 kB)
# Collecting lightning>=2.0.1 (from pyannote.audio==3.0.1->whisperx==3.1.1)
#   Obtaining dependency information for lightning>=2.0.1 from https://files.pythonhosted.org/packages/08/c7/8c33e2660161a99923fa9b46c72c31884efd482b89f7ead970cee5c0072a/lightning-2.1.0-py3-none-any.whl.metadata
#   Using cached lightning-2.1.0-py3-none-any.whl.metadata (64 kB)
# Collecting omegaconf<3.0,>=2.1 (from pyannote.audio==3.0.1->whisperx==3.1.1)
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# INFO: pip is looking at multiple versions of pyannote-audio to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement onnxruntime-gpu>=1.16.0 (from pyannote-audio) (from versions: none)
# ERROR: No matching distribution found for onnxruntime-gpu>=1.16.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip

# %%
import whisperx
import gc 

device = "cuda" 
audio_file = "audio.mp3"
batch_size = 16 # reduce if low on GPU mem
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)

# 1. Transcribe with original whisper (batched)
model = whisperx.load_model("large-v2", device, compute_type=compute_type)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/jamesphoughton/github/deliberation-video-analysis/testWhisperX.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/jamesphoughton/github/deliberation-video-analysis/testWhisperX.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import whisperx
#       <a href='vscode-notebook-cell:/Users/jamesphoughton/github/deliberation-video-analysis/testWhisperX.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import gc
#       <a href='vscode-notebook-cell:/Users/jamesphoughton/github/deliberation-video-analysis/testWhisperX.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> device = "cuda"
#
# ModuleNotFoundError: No module named 'whisperx'

# %%
audio = whisperx.load_audio(audio_file)
result = model.transcribe(audio, batch_size=batch_size)
